# %% [markdown]
# ## Notes
# This file contains the ResNet18 model where we added deformed convolutions to after layers to the model.
#
# The idea is that we put the output of a regular convolution filter into the deformable convolution layer to learn the mapping after the image is passed through a convolution layer, instead of just the convolution layer. Instead of just using a bigger convolution filter, we want to see if we can use deformable convolution to learn important features of data points outside the regular convolution layer.

# %%
# CHANGE THIS IF YOU NOT ON COLAB
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install numpy
# !pip install torch
# !pip install torchvision
# !pip install jupyter
# !pip install matplotlib
# !pip install pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: numpy in ./.conda/envs/venv/lib/python3.10/site-packages (1.26.1)
# Requirement already satisfied: torch in ./.conda/envs/venv/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: filelock in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/envs/venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.52)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/envs/venv/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in ./.conda/envs/venv/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: numpy in ./.conda/envs/venv/lib/python3.10/site-packages (from torchvision) (1.26.1)
# Requirement already satisfied: requests in ./.conda/envs/venv/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from torchvision) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: filelock in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (4.8.0)
# Requirement already satisfied: sympy in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (1.12)
# Requirement already satisfied: networkx in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from torch==2.1.0->torchvision) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/envs/venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->torchvision) (12.3.52)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/venv/lib/python3.10/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from jinja2->torch==2.1.0->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/envs/venv/lib/python3.10/site-packages (from sympy->torch==2.1.0->torchvision) (1.3.0)
# Requirement already satisfied: jupyter in ./.conda/envs/venv/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: notebook in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (6.5.6)
# Requirement already satisfied: qtconsole in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (5.4.4)
# Requirement already satisfied: jupyter-console in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (7.10.0)
# Requirement already satisfied: ipykernel in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (6.14.0)
# Requirement already satisfied: ipywidgets in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter) (8.1.1)
# Requirement already satisfied: debugpy>=1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (8.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (1.5.8)
# Requirement already satisfied: packaging in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: traitlets>=5.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipykernel->jupyter) (5.13.0)
# Requirement already satisfied: comm>=0.1.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipywidgets->jupyter) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipywidgets->jupyter) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipywidgets->jupyter) (3.0.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-console->jupyter) (5.5.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-console->jupyter) (3.0.39)
# Requirement already satisfied: pygments in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-console->jupyter) (2.16.1)
# Requirement already satisfied: pyzmq>=17 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-console->jupyter) (23.2.0)
# Requirement already satisfied: beautifulsoup4 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (2.1.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: argon2-cffi in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (23.1.0)
# Requirement already satisfied: ipython-genutils in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (0.15.0)
# Requirement already satisfied: prometheus-client in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (0.18.0)
# Requirement already satisfied: nbclassic>=0.4.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from notebook->jupyter) (1.0.0)
# Requirement already satisfied: qtpy>=2.4.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in ./.conda/envs/venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: backcall in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: decorator in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: pickleshare in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (68.0.0)
# Requirement already satisfied: stack-data in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: entrypoints in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.3)
# Requirement already satisfied: fastjsonschema in ./.conda/envs/venv/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in ./.conda/envs/venv/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (4.19.2)
# Requirement already satisfied: wcwidth in ./.conda/envs/venv/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.9)
# Requirement already satisfied: ptyprocess in ./.conda/envs/venv/lib/python3.10/site-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.conda/envs/venv/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.conda/envs/venv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.7.1)
# Requirement already satisfied: websocket-client in ./.conda/envs/venv/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: executing>=1.2.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in ./.conda/envs/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/venv/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./.conda/envs/venv/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.1.3)
# Requirement already satisfied: pycparser in ./.conda/envs/venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Requirement already satisfied: matplotlib in ./.conda/envs/venv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/venv/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in ./.conda/envs/venv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./.conda/envs/venv/lib/python3.10/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/envs/venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in ./.conda/envs/venv/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.conda/envs/venv/lib/python3.10/site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in ./.conda/envs/venv/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.conda/envs/venv/lib/python3.10/site-packages (from scikit-learn) (3.2.0)

# %%
import pylab
import numpy as np
import pandas as pd
import math

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torch.nn.functional as F

import torchvision
from torchvision import datasets, transforms, models, ops
from torchvision.models.resnet import ResNet, BasicBlock

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import scipy
import matplotlib.pyplot as plt
from PIL import Image
import os
import shutil
import time
from tempfile import TemporaryDirectory

# %%
data_dir = './'
drive_dir = './drive/MyDrive/SC4001'
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# CHANGE THIS IF YOU NOT ON COLAB
print(f"Downloading Training dataset:")
train_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='train', transform=data_transforms['train'], download=True)
# train_dataset = datasets.Flowers102(root=os.path.join(drive_dir, "train"), split='train', transform=data_transforms['train'], download=True)

print(f"Downloading Validation dataset:")
val_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='val', transform=data_transforms['val'])
# val_dataset = datasets.Flowers102(root=os.path.join(drive_dir, "train"), split='val', transform=data_transforms['val'])

print(f"Downloading Test dataset:")
test_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='test', transform=data_transforms['test'])
# test_dataset = datasets.Flowers102(root=os.path.join(drive_dir, "train"), split='test', transform=data_transforms['test'])
# Out:
# Downloading Training dataset:
# Downloading Validation dataset:
# Downloading Test dataset:

# %%
batch_size = 4
datasets = {
    'train': train_dataset,
    'val': val_dataset,
    'test': test_dataset
}

# print(f"{len(train_dataset._labels)}")
dataloaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(dataloaders[x].dataset) for x in ['train', 'val', 'test']}
# class_names = image_datasets['train'].classes

print(f"dataloaders: {dataloaders}")
print(f"Dataset sizes: {dataset_sizes}")
# Out:
# dataloaders: {'train': <torch.utils.data.dataloader.DataLoader object at 0x2aab988bd630>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x2aab988bcf10>, 'test': <torch.utils.data.dataloader.DataLoader object at 0x2aab988bd9c0>}
# Dataset sizes: {'train': 1020, 'val': 1020, 'test': 6149}

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # CHANGE THIS IF YOU NOT ON COLAB
    checkpoint_path = './model_checkpoints'
#     checkpoint_path = './drive/MyDrive/SC4001/model_checkpoints'
    train_loss, train_acc = [], []
    val_loss, val_acc = [], []
    # Create a temporary directory to save training checkpoints
    # with TemporaryDirectory() as tempdir:
    best_model_params_path = os.path.join(checkpoint_path, 't_deformed_aft_conv_resnet18.pt')

    torch.save(model.state_dict(), best_model_params_path)
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss:\t{epoch_loss:.4f}\tAcc:\t{epoch_acc:.4f}')

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            elif phase == 'val':
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                torch.save(model.state_dict(), best_model_params_path)

        print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, train_loss, train_acc, val_loss, val_acc

# %% [markdown]
# ## This is where we create our modified ResNet18 Convolutional Neural Network.
#
# We first initialise the model by inheiriting from the original ResNet architecture. We create the model in the same format as ResNet18, with the following code:
# `super(deformed_CNN, self).__init__(BasicBlock, [2, 2, 2, 2])`
#
# We then create the deformable convolution filters for each layer of the ResNet18 architecture. We will mainly focus on the `conv1` layer of the architecture, as any more deformable layers added to the model results in a very poor accuracy.

# %%
def calc_dim(layer, kernel_size, stride, padding):
    """
    This function is used to calculate the spatial dimension for each layer throughout the ResNet18 architecture. 
    """
    # print(f"Spatial Dimension: {math.floor(((layer - kernel_size + 2*(padding)) / stride) + 1)}")
    return math.floor(((layer - kernel_size + 2*(padding)) / stride) + 1)

def calc_depth(depth, name, tracking):
    """
    This function is used to calculate the depth of the filters for each layer throughout the ResNet18 architecture. 
    """
    curr_layer = name.split('.')[0]
    # print(f"{name} = {tracking}")
    if curr_layer == tracking:
        return depth, True, curr_layer
    else:
        return depth * 2, False, curr_layer

class deformed_CNN(ResNet):
    def __init__(self, batch_size, device):
        """
        We stored the offsets and weights for the deformed convolution layer here when we initialized the model.
        We used the calc_dim() function and calc_depth() function to calculate the values for the required parameters in deformed_conv2d.
        There is an issue where if the last batch of images in the dataloader is not the same size as the rest, it will crash.
        We fixed the issue by modifying the batch size of the dataloader for the last batch in the forward() function.
        """
        super(deformed_CNN, self).__init__(BasicBlock, [2, 2, 2, 2])
        self.offsets = {}
        self.weights = {}
        self.batch_size = batch_size
        # input image size before conv1 layer
        self.dim = 224
        # input image depth after conv1 layer
        self.channel = 64
        current_layer = "layer1"
        self.device = device
        
        # Here, we are creating the offset and weights for the deformed convolution layers and 
        # storing them for the forward function. 
        for name, mod in self.named_modules():
            if "conv" in name and "layer" not in name:
                # print(f"name: {name}")
                self.dim = calc_dim(
                    self.dim,
                    self.get_submodule(f"{name}").kernel_size[0],
                    self.get_submodule(f"{name}").stride[0],
                    self.get_submodule(f"{name}").padding[0]
                )
                self.offsets[name] = torch.rand(
                    self.batch_size,
                    2 * 1 * self.get_submodule(f"{name}").kernel_size[0] * self.get_submodule(f"{name}").kernel_size[0],
                    self.dim,
                    self.dim
                ).to(self.device)
                self.weights[name] = torch.rand(
                    self.channel,
                    self.channel,
                    self.get_submodule(f"{name}").kernel_size[0],
                    self.get_submodule(f"{name}").kernel_size[0]
                ).to(self.device)
            elif "maxpool" in name:
                # print(f"name: {name}")
                self.dim = calc_dim(
                    self.dim,
                    self.get_submodule(f"{name}").kernel_size,
                    self.get_submodule(f"{name}").stride,
                    self.get_submodule(f"{name}").padding
                )
            elif "layer" in name and "conv" in name:
                # print(f"name: {name}")
                self.dim = calc_dim(
                    self.dim,
                    self.get_submodule(f"{name}").kernel_size[0],
                    self.get_submodule(f"{name}").stride[0],
                    self.get_submodule(f"{name}").padding[0]
                )
                if ".1.conv2" in name:
                    self.offsets[name] = torch.rand(
                        self.batch_size,
                        2 * 1 * self.get_submodule(f"{name}").kernel_size[0] * self.get_submodule(f"{name}").kernel_size[0],
                        self.dim,
                        self.dim
                    ).to(self.device)
                    new_channel, truth, current_layer = calc_depth(self.channel, name, current_layer)
                    # print(f"{name}\tFeature map depth: {new_channel}")
                    if not truth:
                        self.channel = new_channel
                    self.weights[name] = torch.rand(
                        self.channel,
                        self.channel,
                        self.get_submodule(f"{name}").kernel_size[0],
                        self.get_submodule(f"{name}").kernel_size[0]
                    ).to(self.device)

    def forward(self, x):
        """
        The if condition is to check if the batch size is wrong. 
        This is mainly applied to the last batch of the data as they are not always a multiple of 4, 
        which is our defined batch size.
        
        We pass the output of `conv1` into the deformed_conv2d layer to get `out`,
        before passing `out` into the rest of the network. 
        """
        # print(f"{self.conv1(x).detach().numpy()[0].shape}")
        if len(x) != self.batch_size:
            print(f"LAST LAYER: {len(x)}")
            self.offsets['conv1'] = torch.rand(
                len(x),
                2 * 1 * self.get_submodule(f"conv1").kernel_size[0] * self.get_submodule(f"conv1").kernel_size[0],
                112,
                112
            ).to(self.device)

            self.offsets['layer1.1.conv2'] = torch.rand(
                len(x),
                2 * 1 * self.get_submodule(f"conv1").kernel_size[0] * self.get_submodule(f"conv1").kernel_size[0],
                56,
                56
            ).to(self.device)

            self.offsets['layer2.1.conv2'] = torch.rand(
                len(x),
                2 * 1 * self.get_submodule(f"conv1").kernel_size[0] * self.get_submodule(f"conv1").kernel_size[0],
                28,
                28
            ).to(self.device)

            self.offsets['layer3.1.conv2'] = torch.rand(
                len(x),
                2 * 1 * self.get_submodule(f"conv1").kernel_size[0] * self.get_submodule(f"conv1").kernel_size[0],
                14,
                14
            ).to(self.device)

            self.offsets['layer4.1.conv2'] = torch.rand(
                len(x),
                2 * 1 * self.get_submodule(f"conv1").kernel_size[0] * self.get_submodule(f"conv1").kernel_size[0],
                7,
                7
            ).to(self.device)

        relu = nn.ReLU()
        
        # Here, we pass `x` into the `conv1` layer, 
        # then pass the output of the `conv1` layer into the deformable convolution layer. 
        out = self.conv1(x)
        # print(f"shape: {self.conv1(x).detach().numpy().shape}")
        out = ops.deform_conv2d(
            out,
            self.offsets['conv1'],
            self.weights['conv1'],
            stride=1,
            padding=self.conv1.padding[0]
        )
        out = self.bn1(out)
        out = relu(out)
        out = self.maxpool(out)
        out = self.layer1(out)
        # out = ops.deform_conv2d(
        #    out,
        #    self.offsets['layer1.1.conv2'],
        #    self.weights['layer1.1.conv2'],
        #    stride=1,
        #    padding=self.layer1[1].conv2.padding[0]
        # )

        out = self.layer2(out)
        # out = ops.deform_conv2d(
        #     out,
        #     self.offsets['layer2.1.conv2'],
        #     self.weights['layer2.1.conv2'],
        #     stride=1,
        #     padding=self.layer2[1].conv2.padding[0]
        # )

        out = self.layer3(out)
        # out = ops.deform_conv2d(
        #     out,
        #     self.offsets['layer3.1.conv2'],
        #     self.weights['layer3.1.conv2'],
        #     stride=1,
        #     padding=self.layer3[1].conv2.padding[0]
        # )

        out = self.layer4(out)
        # out = ops.deform_conv2d(
        #     out,
        #     self.offsets['layer4.1.conv2'],
        #     self.weights['layer4.1.conv2'],
        #     stride=1,
        #     padding=self.layer4[1].conv2.padding[0]
        # )

        out = self.avgpool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)

        return out

# %%
# !nvcc --version

# %%
# CHANGE THIS IF YOU NOT ON COLAB
# deformed_model_path = './drive/MyDrive/SC4001/model_checkpoints/deformed_resnet18.pt'
deformed_model_path = './model_checkpoints/deformed_aft_conv_resnet18.pt'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

check_file = os.path.exists(deformed_model_path)
if check_file:
    # Loading my saved deformed model weights into model
    print(f"Loading model from checkpoint")
    model = deformed_CNN(batch_size, device)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 102)
    temp = torch.load(deformed_model_path)
    model.load_state_dict(temp.state_dict())
#     model.load_state_dict(torch.load(deformed_model_path))
else:
    # Saving resnet original weights
    print(f"Model checkpoint does not exist.\nDownloading new model...")
    model_resnet = models.resnet18(weights='IMAGENET1K_V1')
    checkpoint_path = 'model_checkpoints'
    # CHANGE THIS IF NOT USING GOOGLE DRIVE
    og_resnet_path = os.path.join(data_dir, checkpoint_path, 'og_resnet.pt')
#     og_resnet_path = os.path.join(drive_dir, checkpoint_path, 'og_resnet.pt')
    torch.save(model_resnet.state_dict(), og_resnet_path)

    # Loading resnet original weights into my deformed model
    model = deformed_CNN(batch_size, device)
    model.load_state_dict(torch.load(og_resnet_path))

    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 102)


model = model.to(device)
model.cuda()

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 50 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=200, gamma=0.1)
# Out:
# Device: cuda:0
# Model checkpoint does not exist.
# Downloading new model...

# %%
no_epochs = 100

model, train_loss, train_acc, val_loss, val_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=no_epochs)
# for inputs, labels in dataloaders['train']:
#     print(f"inputs:\t{len(inputs)}")
#     outputs = model(inputs)
#     print(f"outputs: {outputs.detach().numpy().shape}")
#     break
# Out:
# Epoch 0/99
# ----------
# train Loss:	4.8692	Acc:	0.0118
# val Loss:	4.6328	Acc:	0.0333
#
# Training complete in 0m 24s
# Best val Acc: 0.033333
# Epoch 1/99
# ----------
# train Loss:	4.6640	Acc:	0.0275
# val Loss:	4.3053	Acc:	0.0637
#
# Training complete in 0m 45s
# Best val Acc: 0.063725
# Epoch 2/99
# ----------
# train Loss:	4.4340	Acc:	0.0451
# val Loss:	4.0420	Acc:	0.1029
#
# Training complete in 1m 6s
# Best val Acc: 0.102941
# Epoch 3/99
# ----------
# train Loss:	4.3014	Acc:	0.0578
# val Loss:	3.9590	Acc:	0.0971
#
# Training complete in 1m 27s
# Best val Acc: 0.102941
# Epoch 4/99
# ----------
# train Loss:	4.2940	Acc:	0.0500
# val Loss:	3.9926	Acc:	0.1196
#
# Training complete in 1m 49s
# Best val Acc: 0.119608
# Epoch 5/99
# ----------
# train Loss:	4.1489	Acc:	0.0716
# val Loss:	3.8612	Acc:	0.1353
#
# Training complete in 2m 10s
# Best val Acc: 0.135294
# Epoch 6/99
# ----------
# train Loss:	3.9502	Acc:	0.0980
# val Loss:	3.9006	Acc:	0.1333
#
# Training complete in 2m 31s
# Best val Acc: 0.135294
# Epoch 7/99
# ----------
# train Loss:	3.9578	Acc:	0.0931
# val Loss:	3.6605	Acc:	0.1578
#
# Training complete in 2m 52s
# Best val Acc: 0.157843
# Epoch 8/99
# ----------
# train Loss:	3.7904	Acc:	0.1039
# val Loss:	3.5612	Acc:	0.1667
#
# Training complete in 3m 13s
# Best val Acc: 0.166667
# Epoch 9/99
# ----------
# train Loss:	3.5933	Acc:	0.1833
# val Loss:	3.2731	Acc:	0.2245
#
# Training complete in 3m 36s
# Best val Acc: 0.224510
# Epoch 10/99
# ----------
# train Loss:	3.4851	Acc:	0.1833
# val Loss:	3.2339	Acc:	0.2529
#
# Training complete in 3m 57s
# Best val Acc: 0.252941
# Epoch 11/99
# ----------
# train Loss:	3.2922	Acc:	0.2108
# val Loss:	2.8253	Acc:	0.2971
#
# Training complete in 4m 18s
# Best val Acc: 0.297059
# Epoch 12/99
# ----------
# train Loss:	3.0934	Acc:	0.2539
# val Loss:	2.6722	Acc:	0.3373
#
# Training complete in 4m 39s
# Best val Acc: 0.337255
# Epoch 13/99
# ----------
# train Loss:	2.9658	Acc:	0.2637
# val Loss:	2.5014	Acc:	0.3804
#
# Training complete in 5m 0s
# Best val Acc: 0.380392
# Epoch 14/99
# ----------
# train Loss:	2.8093	Acc:	0.3225
# val Loss:	2.5319	Acc:	0.3804
#
# Training complete in 5m 21s
# Best val Acc: 0.380392
# Epoch 15/99
# ----------
# train Loss:	2.7952	Acc:	0.3029
# val Loss:	2.5748	Acc:	0.3745
#
# Training complete in 5m 42s
# Best val Acc: 0.380392
# Epoch 16/99
# ----------
# train Loss:	2.8421	Acc:	0.3127
# val Loss:	2.7786	Acc:	0.3471
#
# Training complete in 6m 3s
# Best val Acc: 0.380392
# Epoch 17/99
# ----------
# train Loss:	2.7828	Acc:	0.3284
# val Loss:	2.5522	Acc:	0.3755
#
# Training complete in 6m 24s
# Best val Acc: 0.380392
# Epoch 18/99
# ----------
# train Loss:	2.6997	Acc:	0.3343
# val Loss:	2.6189	Acc:	0.3686
#
# Training complete in 6m 45s
# Best val Acc: 0.380392
# Epoch 19/99
# ----------
# train Loss:	2.7919	Acc:	0.2971
# val Loss:	2.4567	Acc:	0.4000
#
# Training complete in 7m 7s
# Best val Acc: 0.400000
# Epoch 20/99
# ----------
# train Loss:	2.7009	Acc:	0.3333
# val Loss:	2.3445	Acc:	0.4108
#
# Training complete in 7m 28s
# Best val Acc: 0.410784
# Epoch 21/99
# ----------
# train Loss:	2.4658	Acc:	0.4000
# val Loss:	2.2645	Acc:	0.4422
#
# Training complete in 7m 49s
# Best val Acc: 0.442157
# Epoch 22/99
# ----------
# train Loss:	2.3685	Acc:	0.4010
# val Loss:	2.2784	Acc:	0.4618
#
# Training complete in 8m 10s
# Best val Acc: 0.461765
# Epoch 23/99
# ----------
# train Loss:	2.2748	Acc:	0.4216
# val Loss:	2.1068	Acc:	0.4902
#
# Training complete in 8m 32s
# Best val Acc: 0.490196
# Epoch 24/99
# ----------
# train Loss:	2.2188	Acc:	0.4275
# val Loss:	2.7585	Acc:	0.3686
#
# Training complete in 8m 53s
# Best val Acc: 0.490196
# Epoch 25/99
# ----------
# train Loss:	2.1395	Acc:	0.4618
# val Loss:	2.1354	Acc:	0.5088
#
# Training complete in 9m 15s
# Best val Acc: 0.508824
# Epoch 26/99
# ----------
# train Loss:	2.1240	Acc:	0.4745
# val Loss:	2.2491	Acc:	0.4922
#
# Training complete in 9m 35s
# Best val Acc: 0.508824
# Epoch 27/99
# ----------
# train Loss:	2.0218	Acc:	0.4902
# val Loss:	2.2945	Acc:	0.4775
#
# Training complete in 9m 56s
# Best val Acc: 0.508824
# Epoch 28/99
# ----------
# train Loss:	2.0451	Acc:	0.4931
# val Loss:	1.9561	Acc:	0.5206
#
# Training complete in 10m 18s
# Best val Acc: 0.520588
# Epoch 29/99
# ----------
# train Loss:	1.9665	Acc:	0.4833
# val Loss:	1.9995	Acc:	0.5118
#
# Training complete in 10m 38s
# Best val Acc: 0.520588
# Epoch 30/99
# ----------
# train Loss:	2.0784	Acc:	0.4853
# val Loss:	1.8654	Acc:	0.5451
#
# Training complete in 10m 60s
# Best val Acc: 0.545098
# Epoch 31/99
# ----------
# train Loss:	1.9681	Acc:	0.5020
# val Loss:	1.9447	Acc:	0.5176
#
# Training complete in 11m 21s
# Best val Acc: 0.545098
# Epoch 32/99
# ----------
# train Loss:	1.8771	Acc:	0.5245
# val Loss:	1.8397	Acc:	0.5480
#
# Training complete in 11m 42s
# Best val Acc: 0.548039
# Epoch 33/99
# ----------
# train Loss:	1.8021	Acc:	0.5431
# val Loss:	2.1025	Acc:	0.4941
#
# Training complete in 12m 4s
# Best val Acc: 0.548039
# Epoch 34/99
# ----------
# train Loss:	1.8152	Acc:	0.5402
# val Loss:	1.8145	Acc:	0.5706
#
# Training complete in 12m 25s
# Best val Acc: 0.570588
# Epoch 35/99
# ----------
# train Loss:	1.8328	Acc:	0.5216
# val Loss:	1.7849	Acc:	0.5618
#
# Training complete in 12m 46s
# Best val Acc: 0.570588
# Epoch 36/99
# ----------
# train Loss:	1.6915	Acc:	0.5735
# val Loss:	1.8074	Acc:	0.5706
#
# Training complete in 13m 7s
# Best val Acc: 0.570588
# Epoch 37/99
# ----------
# train Loss:	1.6415	Acc:	0.5794
# val Loss:	1.7338	Acc:	0.5912
#
# Training complete in 13m 29s
# Best val Acc: 0.591176
# Epoch 38/99
# ----------
# train Loss:	1.7278	Acc:	0.5510
# val Loss:	1.9116	Acc:	0.5392
#
# Training complete in 13m 50s
# Best val Acc: 0.591176
# Epoch 39/99
# ----------
# train Loss:	1.6706	Acc:	0.5892
# val Loss:	1.8076	Acc:	0.5608
#
# Training complete in 14m 11s
# Best val Acc: 0.591176
# Epoch 40/99
# ----------
# train Loss:	1.7362	Acc:	0.5676
# val Loss:	1.7336	Acc:	0.5735
#
# Training complete in 14m 31s
# Best val Acc: 0.591176
# Epoch 41/99
# ----------
# train Loss:	1.7142	Acc:	0.5676
# val Loss:	2.0192	Acc:	0.5284
#
# Training complete in 14m 52s
# Best val Acc: 0.591176
# Epoch 42/99
# ----------
# train Loss:	1.6869	Acc:	0.5716
# val Loss:	1.9646	Acc:	0.5402
#
# Training complete in 15m 13s
# Best val Acc: 0.591176
# Epoch 43/99
# ----------
# train Loss:	1.6406	Acc:	0.5775
# val Loss:	1.7940	Acc:	0.5765
#
# Training complete in 15m 34s
# Best val Acc: 0.591176
# Epoch 44/99
# ----------
# train Loss:	1.7373	Acc:	0.5578
# val Loss:	2.0834	Acc:	0.5186
#
# Training complete in 15m 55s
# Best val Acc: 0.591176
# Epoch 45/99
# ----------
# train Loss:	1.6798	Acc:	0.5637
# val Loss:	1.7239	Acc:	0.5637
#
# Training complete in 16m 16s
# Best val Acc: 0.591176
# Epoch 46/99
# ----------
# train Loss:	1.6577	Acc:	0.5706
# val Loss:	1.6741	Acc:	0.6137
#
# Training complete in 16m 37s
# Best val Acc: 0.613725
# Epoch 47/99
# ----------
# train Loss:	1.7362	Acc:	0.5745
# val Loss:	1.9017	Acc:	0.5480
#
# Training complete in 16m 58s
# Best val Acc: 0.613725
# Epoch 48/99
# ----------
# train Loss:	1.6667	Acc:	0.5667
# val Loss:	1.7332	Acc:	0.6020
#
# Training complete in 17m 19s
# Best val Acc: 0.613725
# Epoch 49/99
# ----------
# train Loss:	1.6718	Acc:	0.5716
# val Loss:	1.8007	Acc:	0.5735
#
# Training complete in 17m 39s
# Best val Acc: 0.613725
# Epoch 50/99
# ----------
# train Loss:	1.6075	Acc:	0.5961
# val Loss:	1.4944	Acc:	0.6088
#
# Training complete in 18m 0s
# Best val Acc: 0.613725
# Epoch 51/99
# ----------
# train Loss:	1.6342	Acc:	0.5892
# val Loss:	1.7781	Acc:	0.5706
#
# Training complete in 18m 21s
# Best val Acc: 0.613725
# Epoch 52/99
# ----------
# train Loss:	1.6011	Acc:	0.6186
# val Loss:	1.5926	Acc:	0.5902
#
# Training complete in 18m 42s
# Best val Acc: 0.613725
# Epoch 53/99
# ----------
# train Loss:	1.6710	Acc:	0.5755
# val Loss:	1.8987	Acc:	0.5657
#
# Training complete in 19m 3s
# Best val Acc: 0.613725
# Epoch 54/99
# ----------
# train Loss:	1.6583	Acc:	0.5873
# val Loss:	1.7131	Acc:	0.5961
#
# Training complete in 19m 24s
# Best val Acc: 0.613725
# Epoch 55/99
# ----------
# train Loss:	1.6370	Acc:	0.5775
# val Loss:	1.7581	Acc:	0.5902
#
# Training complete in 19m 45s
# Best val Acc: 0.613725
# Epoch 56/99
# ----------
# train Loss:	1.5935	Acc:	0.6029
# val Loss:	1.7437	Acc:	0.5892
#
# Training complete in 20m 6s
# Best val Acc: 0.613725
# Epoch 57/99
# ----------
# train Loss:	1.5982	Acc:	0.5980
# val Loss:	1.8825	Acc:	0.5686
#
# Training complete in 20m 27s
# Best val Acc: 0.613725
# Epoch 58/99
# ----------
# train Loss:	1.5908	Acc:	0.5706
# val Loss:	1.7904	Acc:	0.5765
#
# Training complete in 20m 48s
# Best val Acc: 0.613725
# Epoch 59/99
# ----------
# train Loss:	1.5922	Acc:	0.5824
# val Loss:	2.0275	Acc:	0.5402
#
# Training complete in 21m 9s
# Best val Acc: 0.613725
# Epoch 60/99
# ----------
# train Loss:	1.5407	Acc:	0.6039
# val Loss:	1.8442	Acc:	0.5588
#
# Training complete in 21m 29s
# Best val Acc: 0.613725
# Epoch 61/99
# ----------
# train Loss:	1.6806	Acc:	0.5667
# val Loss:	1.9342	Acc:	0.5598
#
# Training complete in 21m 51s
# Best val Acc: 0.613725
# Epoch 62/99
# ----------
# train Loss:	1.7002	Acc:	0.5686
# val Loss:	1.8523	Acc:	0.5569
#
# Training complete in 22m 12s
# Best val Acc: 0.613725
# Epoch 63/99
# ----------
# train Loss:	1.6728	Acc:	0.5814
# val Loss:	1.7396	Acc:	0.5775
#
# Training complete in 22m 33s
# Best val Acc: 0.613725
# Epoch 64/99
# ----------
# train Loss:	1.6460	Acc:	0.5627
# val Loss:	1.7029	Acc:	0.6108
#
# Training complete in 22m 54s
# Best val Acc: 0.613725
# Epoch 65/99
# ----------
# train Loss:	1.6197	Acc:	0.5853
# val Loss:	2.4877	Acc:	0.4559
#
# Training complete in 23m 15s
# Best val Acc: 0.613725
# Epoch 66/99
# ----------
# train Loss:	1.6391	Acc:	0.5843
# val Loss:	1.6053	Acc:	0.6186
#
# Training complete in 23m 36s
# Best val Acc: 0.618627
# Epoch 67/99
# ----------
# train Loss:	1.5511	Acc:	0.6059
# val Loss:	2.0501	Acc:	0.5176
#
# Training complete in 23m 57s
# Best val Acc: 0.618627
# Epoch 68/99
# ----------
# train Loss:	1.5681	Acc:	0.5990
# val Loss:	1.9894	Acc:	0.5696
#
# Training complete in 24m 18s
# Best val Acc: 0.618627
# Epoch 69/99
# ----------
# train Loss:	1.5782	Acc:	0.5931
# val Loss:	1.6868	Acc:	0.6049
#
# Training complete in 24m 38s
# Best val Acc: 0.618627
# Epoch 70/99
# ----------
# train Loss:	1.6009	Acc:	0.5833
# val Loss:	1.7981	Acc:	0.5647
#
# Training complete in 25m 3s
# Best val Acc: 0.618627
# Epoch 71/99
# ----------
# train Loss:	1.6012	Acc:	0.6000
# val Loss:	1.6844	Acc:	0.5873
#
# Training complete in 25m 24s
# Best val Acc: 0.618627
# Epoch 72/99
# ----------
# train Loss:	1.6125	Acc:	0.5912
# val Loss:	1.8367	Acc:	0.5745
#
# Training complete in 25m 46s
# Best val Acc: 0.618627
# Epoch 73/99
# ----------
# train Loss:	1.5459	Acc:	0.6069
# val Loss:	1.8052	Acc:	0.5931
#
# Training complete in 26m 7s
# Best val Acc: 0.618627
# Epoch 74/99
# ----------
# train Loss:	1.5743	Acc:	0.6039
# val Loss:	1.7141	Acc:	0.5843
#
# Training complete in 26m 28s
# Best val Acc: 0.618627
# Epoch 75/99
# ----------
# train Loss:	1.6291	Acc:	0.5657
# val Loss:	1.8225	Acc:	0.5716
#
# Training complete in 26m 49s
# Best val Acc: 0.618627
# Epoch 76/99
# ----------
# train Loss:	1.5803	Acc:	0.5951
# val Loss:	1.9783	Acc:	0.5196
#
# Training complete in 27m 10s
# Best val Acc: 0.618627
# Epoch 77/99
# ----------
# train Loss:	1.5972	Acc:	0.5941
# val Loss:	1.6821	Acc:	0.5794
#
# Training complete in 27m 31s
# Best val Acc: 0.618627
# Epoch 78/99
# ----------
# train Loss:	1.5492	Acc:	0.6127
# val Loss:	1.7056	Acc:	0.6049
#
# Training complete in 27m 52s
# Best val Acc: 0.618627
# Epoch 79/99
# ----------
# train Loss:	1.5858	Acc:	0.5961
# val Loss:	1.6853	Acc:	0.5980
#
# Training complete in 28m 13s
# Best val Acc: 0.618627
# Epoch 80/99
# ----------
# train Loss:	1.5311	Acc:	0.6098
# val Loss:	1.6839	Acc:	0.6039
#
# Training complete in 28m 33s
# Best val Acc: 0.618627
# Epoch 81/99
# ----------
# train Loss:	1.6150	Acc:	0.6069
# val Loss:	1.7260	Acc:	0.5980
#
# Training complete in 28m 54s
# Best val Acc: 0.618627
# Epoch 82/99
# ----------
# train Loss:	1.5387	Acc:	0.6059
# val Loss:	1.7596	Acc:	0.5804
#
# Training complete in 29m 15s
# Best val Acc: 0.618627
# Epoch 83/99
# ----------
# train Loss:	1.5713	Acc:	0.5853
# val Loss:	1.7651	Acc:	0.5667
#
# Training complete in 29m 35s
# Best val Acc: 0.618627
# Epoch 84/99
# ----------
# train Loss:	1.4999	Acc:	0.6049
# val Loss:	1.6362	Acc:	0.5951
#
# Training complete in 29m 56s
# Best val Acc: 0.618627
# Epoch 85/99
# ----------
# train Loss:	1.5356	Acc:	0.6059
# val Loss:	1.6510	Acc:	0.6088
#
# Training complete in 30m 17s
# Best val Acc: 0.618627
# Epoch 86/99
# ----------
# train Loss:	1.5357	Acc:	0.5843
# val Loss:	1.8429	Acc:	0.5745
#
# Training complete in 30m 38s
# Best val Acc: 0.618627
# Epoch 87/99
# ----------
# train Loss:	1.5596	Acc:	0.5980
# val Loss:	1.6475	Acc:	0.6137
#
# Training complete in 30m 59s
# Best val Acc: 0.618627
# Epoch 88/99
# ----------
# train Loss:	1.5866	Acc:	0.5804
# val Loss:	1.6023	Acc:	0.5961
#
# Training complete in 31m 20s
# Best val Acc: 0.618627
# Epoch 89/99
# ----------
# train Loss:	1.5790	Acc:	0.5892
# val Loss:	1.6493	Acc:	0.6029
#
# Training complete in 31m 41s
# Best val Acc: 0.618627
# Epoch 90/99
# ----------
# train Loss:	1.5619	Acc:	0.5931
# val Loss:	1.5674	Acc:	0.6157
#
# Training complete in 32m 2s
# Best val Acc: 0.618627
# Epoch 91/99
# ----------
# train Loss:	1.5744	Acc:	0.6049
# val Loss:	1.5490	Acc:	0.6216
#
# Training complete in 32m 23s
# Best val Acc: 0.621569
# Epoch 92/99
# ----------
# train Loss:	1.4451	Acc:	0.6275
# val Loss:	1.5932	Acc:	0.6029
#
# Training complete in 32m 44s
# Best val Acc: 0.621569
# Epoch 93/99
# ----------
# train Loss:	1.4641	Acc:	0.6176
# val Loss:	1.8588	Acc:	0.5696
#
# Training complete in 33m 5s
# Best val Acc: 0.621569
# Epoch 94/99
# ----------
# train Loss:	1.4575	Acc:	0.6167
# val Loss:	1.7426	Acc:	0.5618
#
# Training complete in 33m 26s
# Best val Acc: 0.621569
# Epoch 95/99
# ----------
# train Loss:	1.6609	Acc:	0.5775
# val Loss:	1.8930	Acc:	0.5696
#
# Training complete in 33m 47s
# Best val Acc: 0.621569
# Epoch 96/99
# ----------
# train Loss:	1.5236	Acc:	0.6118
# val Loss:	1.6569	Acc:	0.6039
#
# Training complete in 34m 12s
# Best val Acc: 0.621569
# Epoch 97/99
# ----------
# train Loss:	1.4997	Acc:	0.6147
# val Loss:	1.6351	Acc:	0.6245
#
# Training complete in 34m 34s
# Best val Acc: 0.624510
# Epoch 98/99
# ----------
# train Loss:	1.3867	Acc:	0.6588
# val Loss:	1.5821	Acc:	0.6216
#
# Training complete in 34m 55s
# Best val Acc: 0.624510
# Epoch 99/99
# ----------
# train Loss:	1.4108	Acc:	0.6402
# val Loss:	1.7007	Acc:	0.5931
#
# Training complete in 35m 17s
# Best val Acc: 0.624510

# %%
torch.save(model, deformed_model_path)

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %% [markdown]
# In the cell below, we visualize how well the model is performing. The model got 3/6 predictions correct.

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                # Changed classes to labels so it corresponds to the labels from dataloader['val']
                ax.set_title(f'Predicted: {preds[j]} | True: {labels[j]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

visualize_model(model)

# %%
def plot_graph(no_epoch, train, val, title):
    plt.figure()
    plt.plot(range(no_epoch), train, label='train')
    plt.plot(range(no_epoch), val, label='val')
    if "Accuracy" in title:
        plt.ylabel("Accuracy")
    elif "Loss" in title:
        plt.ylabel("Loss")
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# Plotting the epoch vs accuracy and epoch vs loss here.
#
# The model's best validation accuracy is at 62.45%.

# %%
for i in range(len(train_acc)):
    train_acc[i] = train_acc[i].cpu()
    val_acc[i] = val_acc[i].cpu()

plot_graph(no_epochs, train_acc, val_acc, "Epoch vs Accuracy")

# %%
plot_graph(no_epochs, train_loss, val_loss, "Epoch vs Loss")

# %%
def test(model):
    was_training = model.training
    model.eval()
    # fig = plt.figure()
    size = len(dataloaders['test'].dataset)
    no_batches = len(dataloaders['test'])
    test_loss, correct = 0, 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_loss += criterion(outputs, labels).item() * inputs.size(0)
            correct += torch.sum(preds == labels.data)
            if i % 50 == 0:
                print(f'Predicted: {preds[0]} | True: {labels[0]}')
            # for j in range(inputs.size()[0]):
            #     images_so_far += 1
                # ax = plt.subplot(num_images//2, 2, images_so_far)
                # ax.axis('off')
                # Changed classes to labels so it corresponds to the labels from dataloader['val']
                # ax.set_title(f'Predicted: {preds[j]} | True: {labels[j]}')
                # imshow(inputs.cpu().data[j])

                # if images_so_far == num_images:
                    # model.train(mode=was_training)
                    # return
    test_loss /= size
    correct = correct.double() / size
    model.train(mode=was_training)
    return test_loss, correct

# %% [markdown]
# Testing the model.
#
# The model has a test accuracy of 56.45%.
#
# It has a significant decrease in accuracy in comparison with the original ResNet18 model (Unfrozen).

# %%
test_loss, test_acc = test(model)
# Out:
# Predicted: 50 | True: 50
# Predicted: 10 | True: 31
# Predicted: 37 | True: 37
# Predicted: 93 | True: 73
# Predicted: 57 | True: 57
# Predicted: 79 | True: 79
# Predicted: 45 | True: 45
# Predicted: 75 | True: 75
# Predicted: 89 | True: 52
# Predicted: 66 | True: 66
# Predicted: 73 | True: 79
# Predicted: 15 | True: 45
# Predicted: 3 | True: 29
# Predicted: 101 | True: 83
# Predicted: 76 | True: 76
# Predicted: 16 | True: 16
# Predicted: 55 | True: 55
# Predicted: 79 | True: 79
# Predicted: 93 | True: 56
# Predicted: 48 | True: 69
# Predicted: 55 | True: 88
# Predicted: 60 | True: 19
# Predicted: 25 | True: 88
# Predicted: 10 | True: 42
# Predicted: 49 | True: 11
# Predicted: 39 | True: 39
# Predicted: 19 | True: 19
# Predicted: 90 | True: 90
# Predicted: 10 | True: 17
# Predicted: 19 | True: 19
# Predicted: 91 | True: 99
# LAST LAYER: 1

# %%
print(f'Test Loss:\t{test_loss:.4f}\tTest Acc:\t{test_acc:.4f}')
# Out:
# Test Loss:	1.9867	Test Acc:	0.5645

# %%
print(f"{model}")
# Out:
# deformed_CNN(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=102, bias=True)
# )
