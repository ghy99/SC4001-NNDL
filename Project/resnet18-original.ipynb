# %% [markdown]
# This file contains the original ResNet18 trained on the flowers102 dataset.
#
# Without freezing the ResNet18 architecture, we trained the network on the flowers102 dataset to learn the weights and get the best performing weights to classify the flowers.
#
# We will use this model's performance as a judge against the modifications that we made towards the ResNet model.
# The required python packages will be installed by running the cell below this.
#
# The code is written such that it needs to be run on GPU.

# %%
# !pip install torch
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install pillow
# !pip install scipy
# !pip install torchvision
# !pip install shutil
# !pip install pylab

# %%
import pylab
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torch.nn.functional as F

import torchvision
from torchvision import datasets, transforms, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import scipy
import matplotlib.pyplot as plt
from PIL import Image
import os
import shutil
import time
from tempfile import TemporaryDirectory

# %% [markdown]
# Here, we are downloading the dataset and storing it into a `./train` folder. We applied the following transformations in the `data_transforms` dictionary.

# %%
data_dir = './'

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print(f"Downloading Training dataset:")
train_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='train', transform=data_transforms['train'], download=True)

print(f"Downloading Validation dataset:")
val_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='val', transform=data_transforms['val'])

print(f"Downloading Test dataset:")
test_dataset = datasets.Flowers102(root=os.path.join(data_dir, "train"), split='test', transform=data_transforms['test'])
# Out:
# Downloading Training dataset:
# Downloading Validation dataset:
# Downloading Test dataset:

# %% [markdown]
# Here, we load the folders into dataloaders of `train`, `val`, `test`. The batch size is initialized as 4.

# %%
datasets = {
    'train': train_dataset,
    'val': val_dataset,
    'test': test_dataset
}

# print(f"{len(train_dataset._labels)}")
dataloaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=4,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(dataloaders[x].dataset) for x in ['train', 'val', 'test']}
# class_names = image_datasets['train'].classes

print(f"dataloaders: {dataloaders}")
print(f"Dataset sizes: {dataset_sizes}")
# Out:
# dataloaders: {'train': <torch.utils.data.dataloader.DataLoader object at 0x2aab9894bd30>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x2aab9894be80>, 'test': <torch.utils.data.dataloader.DataLoader object at 0x2aab988bd4b0>}
# Dataset sizes: {'train': 1020, 'val': 1020, 'test': 6149}

# %%
print(f"dataloader train length: {len(dataloaders['train'].dataset)}")
# Out:
# dataloader train length: 1020

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %% [markdown]
# The function below is to train the model.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    checkpoint_path = './model_checkpoints'
    train_loss, train_acc = [], []
    val_loss, val_acc = [], []
    # Create a temporary directory to save training checkpoints
    # with TemporaryDirectory() as tempdir:
    best_model_params_path = os.path.join(checkpoint_path, 't_resnet18_original_params.pt')

    torch.save(model.state_dict(), best_model_params_path)
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()
            
            # Calculating loss and accuracy
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
        
            print(f'{phase} Loss:\t{epoch_loss:.4f}\tAcc:\t{epoch_acc:.4f}')

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            elif phase == 'val':
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)
                
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                torch.save(model.state_dict(), best_model_params_path)

        print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, train_loss, train_acc, val_loss, val_acc

# %% [markdown]
# Here, we load the ResNet18 model into the variable `model`. We then convert the last fully connected layer to an output of 102 neurons. We load the model to the device.
#
# We used Cross Entropy Loss for the cost function, an SGD optimizer and a learning rate scheduler. However, the learning rate scheduler's step size is set at 200 to allow the model to learn as much as possible.

# %%
model_path = './model_checkpoints/resnet18_original_params.pt'

check_file = os.path.exists(model_path)
if check_file:
    print(f"Loading model from checkpoint")
    model = torch.load(model_path)
else:
    print(f"Model checkpoint does not exist.\nDownloading new model...")
    model = models.resnet18(weights='IMAGENET1K_V1')
    # for param in model.parameters():
    #     param.requires_grad = False
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 102)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=200, gamma=0.1)
# Out:
# Model checkpoint does not exist.
# Downloading new model...
# Device: cuda:0

# %% [markdown]
# Displaying the model architecture.

# %%
for key, val in model.state_dict().items():
    if "mean" in key or "var" in key or "tracked" in key:
        continue
    print(f"{key} : {val.cpu().detach().numpy().shape}")
# Out:
# conv1.weight : (64, 3, 7, 7)
# bn1.weight : (64,)
# bn1.bias : (64,)
# layer1.0.conv1.weight : (64, 64, 3, 3)
# layer1.0.bn1.weight : (64,)
# layer1.0.bn1.bias : (64,)
# layer1.0.conv2.weight : (64, 64, 3, 3)
# layer1.0.bn2.weight : (64,)
# layer1.0.bn2.bias : (64,)
# layer1.1.conv1.weight : (64, 64, 3, 3)
# layer1.1.bn1.weight : (64,)
# layer1.1.bn1.bias : (64,)
# layer1.1.conv2.weight : (64, 64, 3, 3)
# layer1.1.bn2.weight : (64,)
# layer1.1.bn2.bias : (64,)
# layer2.0.conv1.weight : (128, 64, 3, 3)
# layer2.0.bn1.weight : (128,)
# layer2.0.bn1.bias : (128,)
# layer2.0.conv2.weight : (128, 128, 3, 3)
# layer2.0.bn2.weight : (128,)
# layer2.0.bn2.bias : (128,)
# layer2.0.downsample.0.weight : (128, 64, 1, 1)
# layer2.0.downsample.1.weight : (128,)
# layer2.0.downsample.1.bias : (128,)
# layer2.1.conv1.weight : (128, 128, 3, 3)
# layer2.1.bn1.weight : (128,)
# layer2.1.bn1.bias : (128,)
# layer2.1.conv2.weight : (128, 128, 3, 3)
# layer2.1.bn2.weight : (128,)
# layer2.1.bn2.bias : (128,)
# layer3.0.conv1.weight : (256, 128, 3, 3)
# layer3.0.bn1.weight : (256,)
# layer3.0.bn1.bias : (256,)
# layer3.0.conv2.weight : (256, 256, 3, 3)
# layer3.0.bn2.weight : (256,)
# layer3.0.bn2.bias : (256,)
# layer3.0.downsample.0.weight : (256, 128, 1, 1)
# layer3.0.downsample.1.weight : (256,)
# layer3.0.downsample.1.bias : (256,)
# layer3.1.conv1.weight : (256, 256, 3, 3)
# layer3.1.bn1.weight : (256,)
# layer3.1.bn1.bias : (256,)
# layer3.1.conv2.weight : (256, 256, 3, 3)
# layer3.1.bn2.weight : (256,)
# layer3.1.bn2.bias : (256,)
# layer4.0.conv1.weight : (512, 256, 3, 3)
# layer4.0.bn1.weight : (512,)
# layer4.0.bn1.bias : (512,)
# layer4.0.conv2.weight : (512, 512, 3, 3)
# layer4.0.bn2.weight : (512,)
# layer4.0.bn2.bias : (512,)
# layer4.0.downsample.0.weight : (512, 256, 1, 1)
# layer4.0.downsample.1.weight : (512,)
# layer4.0.downsample.1.bias : (512,)
# layer4.1.conv1.weight : (512, 512, 3, 3)
# layer4.1.bn1.weight : (512,)
# layer4.1.bn1.bias : (512,)
# layer4.1.conv2.weight : (512, 512, 3, 3)
# layer4.1.bn2.weight : (512,)
# layer4.1.bn2.bias : (512,)
# fc.weight : (102, 512)
# fc.bias : (102,)

# %% [markdown]
# Model training starts here.
#
# We used 100 epochs.

# %%
no_epochs = 100

model, train_loss, train_acc, val_loss, val_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=no_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss:	4.4736	Acc:	0.0461
# val Loss:	3.1403	Acc:	0.2931
#
# Training complete in 0m 17s
# Best val Acc: 0.293137
# Epoch 1/99
# ----------
# train Loss:	3.3104	Acc:	0.2382
# val Loss:	1.8918	Acc:	0.5284
#
# Training complete in 0m 30s
# Best val Acc: 0.528431
# Epoch 2/99
# ----------
# train Loss:	2.5048	Acc:	0.4255
# val Loss:	1.3049	Acc:	0.6676
#
# Training complete in 0m 43s
# Best val Acc: 0.667647
# Epoch 3/99
# ----------
# train Loss:	2.0546	Acc:	0.5255
# val Loss:	0.9265	Acc:	0.7559
#
# Training complete in 0m 56s
# Best val Acc: 0.755882
# Epoch 4/99
# ----------
# train Loss:	1.6189	Acc:	0.6353
# val Loss:	0.7031	Acc:	0.8216
#
# Training complete in 1m 9s
# Best val Acc: 0.821569
# Epoch 5/99
# ----------
# train Loss:	1.3189	Acc:	0.7059
# val Loss:	0.6462	Acc:	0.8147
#
# Training complete in 1m 21s
# Best val Acc: 0.821569
# Epoch 6/99
# ----------
# train Loss:	1.4172	Acc:	0.6892
# val Loss:	0.5813	Acc:	0.8382
#
# Training complete in 1m 35s
# Best val Acc: 0.838235
# Epoch 7/99
# ----------
# train Loss:	1.1058	Acc:	0.7637
# val Loss:	0.5963	Acc:	0.8343
#
# Training complete in 1m 47s
# Best val Acc: 0.838235
# Epoch 8/99
# ----------
# train Loss:	1.1312	Acc:	0.7627
# val Loss:	0.5441	Acc:	0.8373
#
# Training complete in 1m 60s
# Best val Acc: 0.838235
# Epoch 9/99
# ----------
# train Loss:	1.1796	Acc:	0.7363
# val Loss:	0.5332	Acc:	0.8608
#
# Training complete in 2m 13s
# Best val Acc: 0.860784
# Epoch 10/99
# ----------
# train Loss:	1.0139	Acc:	0.7706
# val Loss:	0.5003	Acc:	0.8667
#
# Training complete in 2m 25s
# Best val Acc: 0.866667
# Epoch 11/99
# ----------
# train Loss:	0.8159	Acc:	0.8304
# val Loss:	0.4752	Acc:	0.8696
#
# Training complete in 2m 38s
# Best val Acc: 0.869608
# Epoch 12/99
# ----------
# train Loss:	0.7444	Acc:	0.8373
# val Loss:	0.4521	Acc:	0.8686
#
# Training complete in 2m 51s
# Best val Acc: 0.869608
# Epoch 13/99
# ----------
# train Loss:	0.8195	Acc:	0.8137
# val Loss:	0.4516	Acc:	0.8824
#
# Training complete in 3m 4s
# Best val Acc: 0.882353
# Epoch 14/99
# ----------
# train Loss:	0.7011	Acc:	0.8549
# val Loss:	0.4547	Acc:	0.8824
#
# Training complete in 3m 16s
# Best val Acc: 0.882353
# Epoch 15/99
# ----------
# train Loss:	0.7484	Acc:	0.8333
# val Loss:	0.4538	Acc:	0.8784
#
# Training complete in 3m 29s
# Best val Acc: 0.882353
# Epoch 16/99
# ----------
# train Loss:	0.7987	Acc:	0.8255
# val Loss:	0.4927	Acc:	0.8716
#
# Training complete in 3m 41s
# Best val Acc: 0.882353
# Epoch 17/99
# ----------
# train Loss:	0.7783	Acc:	0.8284
# val Loss:	0.4588	Acc:	0.8765
#
# Training complete in 3m 54s
# Best val Acc: 0.882353
# Epoch 18/99
# ----------
# train Loss:	0.7772	Acc:	0.8284
# val Loss:	0.4513	Acc:	0.8696
#
# Training complete in 4m 6s
# Best val Acc: 0.882353
# Epoch 19/99
# ----------
# train Loss:	0.7516	Acc:	0.8353
# val Loss:	0.3931	Acc:	0.9029
#
# Training complete in 4m 19s
# Best val Acc: 0.902941
# Epoch 20/99
# ----------
# train Loss:	0.7953	Acc:	0.8255
# val Loss:	0.4597	Acc:	0.8784
#
# Training complete in 4m 32s
# Best val Acc: 0.902941
# Epoch 21/99
# ----------
# train Loss:	0.7079	Acc:	0.8471
# val Loss:	0.4357	Acc:	0.8922
#
# Training complete in 4m 44s
# Best val Acc: 0.902941
# Epoch 22/99
# ----------
# train Loss:	0.7266	Acc:	0.8353
# val Loss:	0.4597	Acc:	0.8647
#
# Training complete in 4m 57s
# Best val Acc: 0.902941
# Epoch 23/99
# ----------
# train Loss:	0.6783	Acc:	0.8510
# val Loss:	0.4170	Acc:	0.8794
#
# Training complete in 5m 9s
# Best val Acc: 0.902941
# Epoch 24/99
# ----------
# train Loss:	0.6640	Acc:	0.8627
# val Loss:	0.4046	Acc:	0.8941
#
# Training complete in 5m 22s
# Best val Acc: 0.902941
# Epoch 25/99
# ----------
# train Loss:	0.7128	Acc:	0.8392
# val Loss:	0.4185	Acc:	0.8873
#
# Training complete in 5m 35s
# Best val Acc: 0.902941
# Epoch 26/99
# ----------
# train Loss:	0.7527	Acc:	0.8343
# val Loss:	0.4223	Acc:	0.8814
#
# Training complete in 5m 48s
# Best val Acc: 0.902941
# Epoch 27/99
# ----------
# train Loss:	0.6120	Acc:	0.8716
# val Loss:	0.4308	Acc:	0.8755
#
# Training complete in 6m 0s
# Best val Acc: 0.902941
# Epoch 28/99
# ----------
# train Loss:	0.7278	Acc:	0.8520
# val Loss:	0.4612	Acc:	0.8676
#
# Training complete in 6m 13s
# Best val Acc: 0.902941
# Epoch 29/99
# ----------
# train Loss:	0.7100	Acc:	0.8461
# val Loss:	0.4577	Acc:	0.8745
#
# Training complete in 6m 26s
# Best val Acc: 0.902941
# Epoch 30/99
# ----------
# train Loss:	0.7170	Acc:	0.8451
# val Loss:	0.4571	Acc:	0.8735
#
# Training complete in 6m 38s
# Best val Acc: 0.902941
# Epoch 31/99
# ----------
# train Loss:	0.6937	Acc:	0.8618
# val Loss:	0.4390	Acc:	0.8863
#
# Training complete in 6m 51s
# Best val Acc: 0.902941
# Epoch 32/99
# ----------
# train Loss:	0.7308	Acc:	0.8529
# val Loss:	0.4464	Acc:	0.8735
#
# Training complete in 7m 3s
# Best val Acc: 0.902941
# Epoch 33/99
# ----------
# train Loss:	0.7504	Acc:	0.8363
# val Loss:	0.4478	Acc:	0.8716
#
# Training complete in 7m 17s
# Best val Acc: 0.902941
# Epoch 34/99
# ----------
# train Loss:	0.6843	Acc:	0.8539
# val Loss:	0.3862	Acc:	0.8990
#
# Training complete in 7m 30s
# Best val Acc: 0.902941
# Epoch 35/99
# ----------
# train Loss:	0.6804	Acc:	0.8431
# val Loss:	0.4398	Acc:	0.8931
#
# Training complete in 7m 43s
# Best val Acc: 0.902941
# Epoch 36/99
# ----------
# train Loss:	0.7164	Acc:	0.8353
# val Loss:	0.4000	Acc:	0.9000
#
# Training complete in 7m 56s
# Best val Acc: 0.902941
# Epoch 37/99
# ----------
# train Loss:	0.6847	Acc:	0.8578
# val Loss:	0.4362	Acc:	0.8941
#
# Training complete in 8m 8s
# Best val Acc: 0.902941
# Epoch 38/99
# ----------
# train Loss:	0.6958	Acc:	0.8510
# val Loss:	0.4473	Acc:	0.8706
#
# Training complete in 8m 21s
# Best val Acc: 0.902941
# Epoch 39/99
# ----------
# train Loss:	0.6625	Acc:	0.8588
# val Loss:	0.4460	Acc:	0.8833
#
# Training complete in 8m 34s
# Best val Acc: 0.902941
# Epoch 40/99
# ----------
# train Loss:	0.6747	Acc:	0.8529
# val Loss:	0.4154	Acc:	0.8902
#
# Training complete in 8m 47s
# Best val Acc: 0.902941
# Epoch 41/99
# ----------
# train Loss:	0.7590	Acc:	0.8304
# val Loss:	0.4210	Acc:	0.8833
#
# Training complete in 8m 59s
# Best val Acc: 0.902941
# Epoch 42/99
# ----------
# train Loss:	0.6104	Acc:	0.8676
# val Loss:	0.4445	Acc:	0.8784
#
# Training complete in 9m 12s
# Best val Acc: 0.902941
# Epoch 43/99
# ----------
# train Loss:	0.7310	Acc:	0.8392
# val Loss:	0.4416	Acc:	0.8784
#
# Training complete in 9m 25s
# Best val Acc: 0.902941
# Epoch 44/99
# ----------
# train Loss:	0.6667	Acc:	0.8529
# val Loss:	0.3978	Acc:	0.8931
#
# Training complete in 9m 38s
# Best val Acc: 0.902941
# Epoch 45/99
# ----------
# train Loss:	0.6925	Acc:	0.8510
# val Loss:	0.4185	Acc:	0.8882
#
# Training complete in 9m 50s
# Best val Acc: 0.902941
# Epoch 46/99
# ----------
# train Loss:	0.6825	Acc:	0.8510
# val Loss:	0.4038	Acc:	0.8922
#
# Training complete in 10m 3s
# Best val Acc: 0.902941
# Epoch 47/99
# ----------
# train Loss:	0.6948	Acc:	0.8510
# val Loss:	0.4400	Acc:	0.8843
#
# Training complete in 10m 15s
# Best val Acc: 0.902941
# Epoch 48/99
# ----------
# train Loss:	0.7391	Acc:	0.8333
# val Loss:	0.4078	Acc:	0.8892
#
# Training complete in 10m 29s
# Best val Acc: 0.902941
# Epoch 49/99
# ----------
# train Loss:	0.6959	Acc:	0.8441
# val Loss:	0.4155	Acc:	0.8833
#
# Training complete in 10m 45s
# Best val Acc: 0.902941
# Epoch 50/99
# ----------
# train Loss:	0.7378	Acc:	0.8343
# val Loss:	0.4180	Acc:	0.8912
#
# Training complete in 10m 58s
# Best val Acc: 0.902941
# Epoch 51/99
# ----------
# train Loss:	0.7067	Acc:	0.8500
# val Loss:	0.4077	Acc:	0.8941
#
# Training complete in 11m 11s
# Best val Acc: 0.902941
# Epoch 52/99
# ----------
# train Loss:	0.6379	Acc:	0.8627
# val Loss:	0.4256	Acc:	0.8775
#
# Training complete in 11m 25s
# Best val Acc: 0.902941
# Epoch 53/99
# ----------
# train Loss:	0.6503	Acc:	0.8618
# val Loss:	0.3989	Acc:	0.8892
#
# Training complete in 11m 39s
# Best val Acc: 0.902941
# Epoch 54/99
# ----------
# train Loss:	0.6948	Acc:	0.8598
# val Loss:	0.4391	Acc:	0.8676
#
# Training complete in 11m 51s
# Best val Acc: 0.902941
# Epoch 55/99
# ----------
# train Loss:	0.6517	Acc:	0.8667
# val Loss:	0.3958	Acc:	0.8892
#
# Training complete in 12m 4s
# Best val Acc: 0.902941
# Epoch 56/99
# ----------
# train Loss:	0.6777	Acc:	0.8569
# val Loss:	0.4518	Acc:	0.8676
#
# Training complete in 12m 16s
# Best val Acc: 0.902941
# Epoch 57/99
# ----------
# train Loss:	0.6914	Acc:	0.8392
# val Loss:	0.4339	Acc:	0.8784
#
# Training complete in 12m 30s
# Best val Acc: 0.902941
# Epoch 58/99
# ----------
# train Loss:	0.6947	Acc:	0.8510
# val Loss:	0.4099	Acc:	0.8863
#
# Training complete in 12m 43s
# Best val Acc: 0.902941
# Epoch 59/99
# ----------
# train Loss:	0.6749	Acc:	0.8471
# val Loss:	0.4195	Acc:	0.8833
#
# Training complete in 12m 55s
# Best val Acc: 0.902941
# Epoch 60/99
# ----------
# train Loss:	0.7209	Acc:	0.8539
# val Loss:	0.4220	Acc:	0.8804
#
# Training complete in 13m 8s
# Best val Acc: 0.902941
# Epoch 61/99
# ----------
# train Loss:	0.7201	Acc:	0.8373
# val Loss:	0.4606	Acc:	0.8804
#
# Training complete in 13m 21s
# Best val Acc: 0.902941
# Epoch 62/99
# ----------
# train Loss:	0.6882	Acc:	0.8471
# val Loss:	0.4694	Acc:	0.8775
#
# Training complete in 13m 34s
# Best val Acc: 0.902941
# Epoch 63/99
# ----------
# train Loss:	0.7008	Acc:	0.8480
# val Loss:	0.4169	Acc:	0.8804
#
# Training complete in 13m 46s
# Best val Acc: 0.902941
# Epoch 64/99
# ----------
# train Loss:	0.6218	Acc:	0.8686
# val Loss:	0.4691	Acc:	0.8608
#
# Training complete in 13m 59s
# Best val Acc: 0.902941
# Epoch 65/99
# ----------
# train Loss:	0.6826	Acc:	0.8500
# val Loss:	0.4357	Acc:	0.8794
#
# Training complete in 14m 12s
# Best val Acc: 0.902941
# Epoch 66/99
# ----------
# train Loss:	0.6967	Acc:	0.8461
# val Loss:	0.4674	Acc:	0.8676
#
# Training complete in 14m 25s
# Best val Acc: 0.902941
# Epoch 67/99
# ----------
# train Loss:	0.6808	Acc:	0.8451
# val Loss:	0.4011	Acc:	0.8922
#
# Training complete in 14m 37s
# Best val Acc: 0.902941
# Epoch 68/99
# ----------
# train Loss:	0.7062	Acc:	0.8480
# val Loss:	0.4397	Acc:	0.8676
#
# Training complete in 14m 50s
# Best val Acc: 0.902941
# Epoch 69/99
# ----------
# train Loss:	0.6225	Acc:	0.8735
# val Loss:	0.4156	Acc:	0.8892
#
# Training complete in 15m 2s
# Best val Acc: 0.902941
# Epoch 70/99
# ----------
# train Loss:	0.6852	Acc:	0.8539
# val Loss:	0.5234	Acc:	0.8618
#
# Training complete in 15m 15s
# Best val Acc: 0.902941
# Epoch 71/99
# ----------
# train Loss:	0.7318	Acc:	0.8343
# val Loss:	0.4078	Acc:	0.8912
#
# Training complete in 15m 27s
# Best val Acc: 0.902941
# Epoch 72/99
# ----------
# train Loss:	0.6878	Acc:	0.8422
# val Loss:	0.4434	Acc:	0.8696
#
# Training complete in 15m 40s
# Best val Acc: 0.902941
# Epoch 73/99
# ----------
# train Loss:	0.7401	Acc:	0.8392
# val Loss:	0.4069	Acc:	0.8843
#
# Training complete in 15m 53s
# Best val Acc: 0.902941
# Epoch 74/99
# ----------
# train Loss:	0.7211	Acc:	0.8402
# val Loss:	0.4460	Acc:	0.8804
#
# Training complete in 16m 6s
# Best val Acc: 0.902941
# Epoch 75/99
# ----------
# train Loss:	0.6980	Acc:	0.8461
# val Loss:	0.3796	Acc:	0.8912
#
# Training complete in 16m 19s
# Best val Acc: 0.902941
# Epoch 76/99
# ----------
# train Loss:	0.7883	Acc:	0.8245
# val Loss:	0.3750	Acc:	0.8951
#
# Training complete in 16m 32s
# Best val Acc: 0.902941
# Epoch 77/99
# ----------
# train Loss:	0.6671	Acc:	0.8608
# val Loss:	0.4322	Acc:	0.8873
#
# Training complete in 16m 44s
# Best val Acc: 0.902941
# Epoch 78/99
# ----------
# train Loss:	0.7190	Acc:	0.8480
# val Loss:	0.4183	Acc:	0.8951
#
# Training complete in 16m 57s
# Best val Acc: 0.902941
# Epoch 79/99
# ----------
# train Loss:	0.7162	Acc:	0.8422
# val Loss:	0.4326	Acc:	0.8775
#
# Training complete in 17m 9s
# Best val Acc: 0.902941
# Epoch 80/99
# ----------
# train Loss:	0.6915	Acc:	0.8490
# val Loss:	0.4119	Acc:	0.8873
#
# Training complete in 17m 22s
# Best val Acc: 0.902941
# Epoch 81/99
# ----------
# train Loss:	0.7077	Acc:	0.8402
# val Loss:	0.4351	Acc:	0.8902
#
# Training complete in 17m 35s
# Best val Acc: 0.902941
# Epoch 82/99
# ----------
# train Loss:	0.7328	Acc:	0.8314
# val Loss:	0.4017	Acc:	0.8912
#
# Training complete in 17m 48s
# Best val Acc: 0.902941
# Epoch 83/99
# ----------
# train Loss:	0.7197	Acc:	0.8500
# val Loss:	0.4871	Acc:	0.8667
#
# Training complete in 18m 0s
# Best val Acc: 0.902941
# Epoch 84/99
# ----------
# train Loss:	0.6796	Acc:	0.8461
# val Loss:	0.3915	Acc:	0.8990
#
# Training complete in 18m 13s
# Best val Acc: 0.902941
# Epoch 85/99
# ----------
# train Loss:	0.7692	Acc:	0.8265
# val Loss:	0.4240	Acc:	0.8990
#
# Training complete in 18m 26s
# Best val Acc: 0.902941
# Epoch 86/99
# ----------
# train Loss:	0.6532	Acc:	0.8667
# val Loss:	0.4028	Acc:	0.8971
#
# Training complete in 18m 38s
# Best val Acc: 0.902941
# Epoch 87/99
# ----------
# train Loss:	0.7109	Acc:	0.8441
# val Loss:	0.4009	Acc:	0.9020
#
# Training complete in 18m 50s
# Best val Acc: 0.902941
# Epoch 88/99
# ----------
# train Loss:	0.6902	Acc:	0.8529
# val Loss:	0.4152	Acc:	0.8873
#
# Training complete in 19m 3s
# Best val Acc: 0.902941
# Epoch 89/99
# ----------
# train Loss:	0.7132	Acc:	0.8412
# val Loss:	0.4589	Acc:	0.8784
#
# Training complete in 19m 16s
# Best val Acc: 0.902941
# Epoch 90/99
# ----------
# train Loss:	0.6795	Acc:	0.8529
# val Loss:	0.4900	Acc:	0.8647
#
# Training complete in 19m 28s
# Best val Acc: 0.902941
# Epoch 91/99
# ----------
# train Loss:	0.6869	Acc:	0.8559
# val Loss:	0.4642	Acc:	0.8814
#
# Training complete in 19m 41s
# Best val Acc: 0.902941
# Epoch 92/99
# ----------
# train Loss:	0.7039	Acc:	0.8451
# val Loss:	0.4265	Acc:	0.8814
#
# Training complete in 19m 54s
# Best val Acc: 0.902941
# Epoch 93/99
# ----------
# train Loss:	0.6822	Acc:	0.8353
# val Loss:	0.4360	Acc:	0.8853
#
# Training complete in 20m 6s
# Best val Acc: 0.902941
# Epoch 94/99
# ----------
# train Loss:	0.7246	Acc:	0.8402
# val Loss:	0.4700	Acc:	0.8667
#
# Training complete in 20m 18s
# Best val Acc: 0.902941
# Epoch 95/99
# ----------
# train Loss:	0.7306	Acc:	0.8402
# val Loss:	0.4255	Acc:	0.8882
#
# Training complete in 20m 31s
# Best val Acc: 0.902941
# Epoch 96/99
# ----------
# train Loss:	0.6358	Acc:	0.8627
# val Loss:	0.4041	Acc:	0.8892
#
# Training complete in 20m 44s
# Best val Acc: 0.902941
# Epoch 97/99
# ----------
# train Loss:	0.7653	Acc:	0.8225
# val Loss:	0.4532	Acc:	0.8775
#
# Training complete in 20m 56s
# Best val Acc: 0.902941
# Epoch 98/99
# ----------
# train Loss:	0.6541	Acc:	0.8725
# val Loss:	0.4108	Acc:	0.8990
#
# Training complete in 21m 9s
# Best val Acc: 0.902941
# Epoch 99/99
# ----------
# train Loss:	0.7357	Acc:	0.8500
# val Loss:	0.4358	Acc:	0.8853
#
# Training complete in 21m 22s
# Best val Acc: 0.902941

# %%
torch.save(model, model_path)

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                # Changed classes to labels so it corresponds to the labels from dataloader['val']
                ax.set_title(f'Predicted: {preds[j]} | True: {labels[j]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# In the cell below, we visualize how the model is performing. We can see that the original model got 6/6 correct.

# %%
visualize_model(model)

# %%
def plot_graph(no_epoch, train, val, title):
    plt.figure()
    plt.plot(range(no_epoch), train, label='train')
    plt.plot(range(no_epoch), val, label='val')
    if "Accuracy" in title:
        plt.ylabel("Accuracy")
    elif "Loss" in title:
        plt.ylabel("Loss")
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# This is the plotting for epoch vs accuracy and epoch vs loss.
#
# We can see that the original ResNet18 model performed very well, at a best validation accuracy value of 0.903.

# %%
for i in range(len(train_acc)):
    train_acc[i] = train_acc[i].cpu()

for i in range(len(val_acc)):
    val_acc[i] = val_acc[i].cpu()
    
plot_graph(no_epochs, train_acc, val_acc, "Epoch vs Accuracy")

# %%
plot_graph(no_epochs, train_loss, val_loss, "Epoch vs Loss")

# %% [markdown]
# This is the function to test the model.

# %%
def test(model):
    was_training = model.training
    model.eval()
    # fig = plt.figure()
    size = len(dataloaders['test'].dataset)
    no_batches = len(dataloaders['test'])
    test_loss, correct = 0, 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            test_loss += criterion(outputs, labels).item() * inputs.size(0)
            correct += torch.sum(preds == labels.data)
            if i % 20 == 0:
                print(f'Predicted: {preds[0]} | True: {labels[0]}')
                
    test_loss /= size
    correct = correct.double() / size
    model.train(mode=was_training)
    return test_loss, correct

# %%
test_loss, test_acc = test(model)
print(f'Test Loss:\t{test_loss:.4f}\tTest Acc:\t{test_acc:.4f}')
# Out:
# Predicted: 77 | True: 77
# Predicted: 72 | True: 72
# Predicted: 30 | True: 30
# Predicted: 45 | True: 45
# Predicted: 17 | True: 17
# Predicted: 49 | True: 49
# Predicted: 94 | True: 94
# Predicted: 80 | True: 80
# Predicted: 34 | True: 34
# Predicted: 18 | True: 18
# Predicted: 79 | True: 79
# Predicted: 97 | True: 97
# Predicted: 74 | True: 74
# Predicted: 13 | True: 28
# Predicted: 48 | True: 91
# Predicted: 59 | True: 59
# Predicted: 92 | True: 92
# Predicted: 100 | True: 100
# Predicted: 87 | True: 87
# Predicted: 73 | True: 73
# Predicted: 29 | True: 29
# Predicted: 17 | True: 17
# Predicted: 17 | True: 95
# Predicted: 101 | True: 101
# Predicted: 93 | True: 93
# Predicted: 6 | True: 6
# Predicted: 87 | True: 87
# Predicted: 72 | True: 72
# Predicted: 28 | True: 28
# Predicted: 40 | True: 40
# Predicted: 15 | True: 73
# Predicted: 82 | True: 82
# Predicted: 70 | True: 70
# Predicted: 36 | True: 36
# Predicted: 89 | True: 89
# Predicted: 13 | True: 13
# Predicted: 27 | True: 27
# Predicted: 98 | True: 98
# Predicted: 55 | True: 55
# Predicted: 86 | True: 86
# Predicted: 67 | True: 67
# Predicted: 88 | True: 88
# Predicted: 93 | True: 93
# Predicted: 45 | True: 45
# Predicted: 1 | True: 1
# Predicted: 93 | True: 93
# Predicted: 94 | True: 94
# Predicted: 72 | True: 77
# Predicted: 67 | True: 89
# Predicted: 60 | True: 60
# Predicted: 52 | True: 52
# Predicted: 41 | True: 41
# Predicted: 86 | True: 86
# Predicted: 72 | True: 72
# Predicted: 51 | True: 51
# Predicted: 80 | True: 80
# Predicted: 45 | True: 45
# Predicted: 62 | True: 62
# Predicted: 45 | True: 45
# Predicted: 6 | True: 6
# Predicted: 72 | True: 72
# Predicted: 60 | True: 60
# Predicted: 35 | True: 35
# Predicted: 14 | True: 14
# Predicted: 18 | True: 50
# Predicted: 95 | True: 95
# Predicted: 58 | True: 58
# Predicted: 50 | True: 50
# Predicted: 75 | True: 75
# Predicted: 91 | True: 29
# Predicted: 64 | True: 64
# Predicted: 49 | True: 49
# Predicted: 29 | True: 29
# Predicted: 100 | True: 88
# Predicted: 70 | True: 70
# Predicted: 76 | True: 76
# Predicted: 48 | True: 16
# Test Loss:	0.4642	Test Acc:	0.8727

# %% [markdown]
# Here, we tested the model on the test dataset. The model had an accuracy of 87.27%.

# %% [markdown]
# Printing the model architecture here.

# %%
print(f"{model}")
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=102, bias=True)
# )
